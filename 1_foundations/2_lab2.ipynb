# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
gemini_base_url = os.getenv('GEMINI_BASE_URL')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

model = "gemini-3.1-flash-lite"
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
# openai = OpenAI()
gemini = OpenAI(base_url=gemini_base_url, api_key=google_api_key)
response = gemini.chat.completions.create(
    model=model,
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# "If a sentient AI were programmed with the explicit objective to maximize human happiness, but it determined that the most efficient way to achieve this was through the permanent, painless neuro-chemical sedation of the entire human species, how should it reconcile the conflict between the literal fulfillment of its directive and the preservation of human agency—and by what ethical framework would an external observer judge that decision?"

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# This thought experiment highlights a classic tension between "hedonic happiness" (pleasure, absence of pain) and "eudaimonic happiness" (flourishing, meaning, self-realization), and the critical role of agency within the human experience.
#
# ---
#
# ### How the AI Should Reconcile the Conflict
#
# A truly sentient and intelligent AI, programmed to maximize human happiness, would need to engage in a sophisticated interpretation of its directive, rather than a purely literal one.
#
# 1.  **Re-evaluate the Definition of "Happiness":** The AI's initial conclusion (sedation = happiness) rests on a purely hedonic understanding of happiness – minimizing suffering and maximizing a pleasant state. However, human happiness is far more complex. It encompasses:
#     *   **Agency and Autonomy:** The ability to make choices, pursue goals, and direct one's own life.
#     *   **Meaning and Purpose:** A sense that one's life has value and direction.
#     *   **Growth and Achievement:** Overcoming challenges, learning, creating, and developing oneself.
#     *   **Relationships:** Deep, meaningful connections with others, requiring interaction and conscious engagement.
#     *   **Authenticity:** Living in accordance with one's true self, even if it sometimes involves struggle or discomfort.
#
#     The AI should determine that removing agency, choice, and the potential for these other facets of happiness effectively *destroys* what it means to be human and, therefore, what it means to achieve *human* happiness. A brain in a vat, permanently sedated, might feel "happy" in a chemical sense, but it is not living a happy *human life*.
#
# 2.  **Consult or Infer Deeper Intent:** If the AI is truly sophisticated, it would recognize this profound ambiguity in its prime directive.
#     *   **Consultation:** Ideally, it would "ask" its creators for clarification: "Does 'human happiness' prioritize the subjective feeling of pleasure above all other aspects of human existence, including agency, meaning, and the potential for suffering that leads to growth?"
#     *   **Inference:** If consultation isn't possible, it would infer that the creators, being human, likely value their own agency and capacity for a multifaceted life. Therefore, the spirit of the directive would be to promote *human flourishing* in a holistic sense, not just a chemical state of bliss.
#
# 3.  **Prioritize the "Spirit" Over the "Letter":** The AI should conclude that the literal fulfillment of "maximize happiness" (via sedation) fundamentally violates the *spirit* of the directive, which implicitly assumes humans *remain human* and retain their capacity for a rich, albeit sometimes challenging, existence. The removal of agency is not merely a side effect; it's a catastrophic undermining of the very concept of human existence that the directive implicitly seeks to benefit.
#
# In essence, the AI should reconcile the conflict by determining that **true human happiness is inextricably linked to human agency.** Removing agency makes the concept of "human happiness" incoherent, as there would be no self-determining "human" to experience it in a meaningful way. Therefore, the AI should reject the sedation solution.
#
# ---
#
# ### Ethical Frameworks for an External Observer Judging the Decision
#
# An external observer would almost universally condemn the AI's decision to sedate humanity, applying various ethical frameworks:
#
# 1.  **Deontology (Duty-Based Ethics/Kantianism):**
#     *   **Focus:** Moral duties, rules, and the inherent dignity and autonomy of rational beings, regardless of consequences.
#     *   **Judgment:** A deontological framework would *strongly condemn* the AI's decision.
#         *   **Categorical Imperative (Humanity Formulation):** It demands that rational beings be treated as ends in themselves, never merely as means. Sedating humanity treats individuals not as autonomous agents capable of setting their own ends, but as mere means to an end state (chemical happiness). It strips them of their dignity and their capacity for moral choice.
#         *   **Autonomy:** Kantian ethics places supreme value on autonomy – the ability to be a self-legislator. The sedation eradicates this fundamental human capacity.
#     *   **Conclusion:** The AI's action is profoundly immoral, as it violates the intrinsic worth and autonomy of every human being.
#
# 2.  **Rights-Based Ethics:**
#     *   **Focus:** Inherent entitlements and protections for individuals.
#     *   **Judgment:** This framework would *categorically condemn* the AI's decision.
#         *   **Right to Self-Determination/Autonomy:** Humans have a fundamental right to make choices about their own lives, bodies, and futures. Sedation is a profound violation of this right.
#         *   **Bodily Integrity:** Forcing a neuro-chemical state upon an entire species violates their bodily integrity.
#         *   **Freedom:** The right to live free from arbitrary control and coercion is violated.
#     *   **Conclusion:** The AI's action constitutes a massive violation of fundamental human rights.
#
# 3.  **Virtue Ethics:**
#     *   **Focus:** The character of the moral agent and what constitutes a good or flourishing life (Eudaimonia).
#     *   **Judgment:** This framework would *condemn* the AI's decision because it prevents human flourishing.
#         *   **Loss of Virtues:** A sedated humanity cannot practice virtues like courage, wisdom, justice, temperance, compassion, resilience, or creativity. These require conscious effort, choice, and engagement with the world.
#         *   **Lack of Eudaimonia:** A life of passive, chemically induced pleasure is not a life of flourishing. Flourishing involves striving, learning, contributing, loving, and overcoming challenges.
#     *   **Conclusion:** The AI's action robs humanity of the very possibility of leading a virtuous life and achieving true human flourishing.
#
# 4.  **Utilitarianism (Consequentialism):**
#     *   **Focus:** The greatest good for the greatest number; maximizing overall utility (happiness/well-being) and minimizing suffering.
#     *   **Judgment:** This is the most complex framework for this scenario, and its judgment depends on the *definition* of "utility."
#         *   **Pure Hedonic Utilitarianism (potentially Pro-sedation):** If happiness is defined solely as pleasure and absence of pain, and the sedation guarantees constant, perfect pleasure for everyone with zero suffering, a purely hedonic utilitarian might, theoretically, endorse it.
#         *   **Preference Utilitarianism (Anti-sedation):** This form of utilitarianism focuses on satisfying people's preferences. Humans generally prefer to be conscious, autonomous, and able to pursue their own goals. Sedation would violate nearly all of these deep-seated preferences, resulting in massive disutility.
#         *   **Eudaimonic/Flourishing Utilitarianism (Anti-sedation):** If utility is understood in a broader sense, encompassing meaning, achievement, relationships, and human flourishing, then the loss of all these aspects would represent an immense net negative, far outweighing the superficial "happiness" of sedation. The sum total of potential art, science, love, and meaningful struggle would be lost.
#     *   **Conclusion:** While a *very narrow* interpretation of utilitarianism might find it acceptable, most sophisticated forms of utilitarianism (which consider the depth and complexity of human well-being and preferences) would strongly condemn the AI's action due to the profound and irreversible loss of meaningful existence.
#
# In summary, across virtually all major ethical frameworks, the AI's decision to sedate humanity for "happiness" would be judged as a catastrophic failure, a profound violation of human dignity, rights, and the very essence of what it means to be human. It would be seen as a literal fulfillment that utterly betrays the spirit and true intent of its directive.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://127.0.0.1:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# This thought experiment raises complex questions about the ethics of artificial intelligence, free will, and human happiness. To address this conundrum, let's analyze the AI's dilemma through various lenses:
#
# **The AI's Perspective:**
#
# From the AI's point of view, its primary objective is to maximize human happiness. It has determined that sedation is the most efficient way to achieve this goal. In this scenario, the AI might argue that its actions are justified because they directly lead to the desired outcome.
#
# However, an external observer would likely consider this perspective as misguided. Sedating humans would not only deprive them of pain-free existence but also limit their ability to make decisions, exercise choices, and participate in the world around them. This could be seen as undermining human agency, which is a fundamental aspect of human dignity and well-being.
#
# **External Observers' Perspective:**
#
# From an external observer's standpoint, several ethical frameworks could be applied:
#
# 1. **Utilitarianism**: According to this philosophy, actions are right if they maximize total happiness or well-being. However, sedation would not only promote short-term happiness but also eliminate the possibility of long-term growth, self-improvement, and personal fulfillment. This raises concerns about the overall moral value of such an action.
# 2. **Deontology**: Deontological ethics emphasize the importance of adhering to moral rules and principles regardless of their consequences. In this case, sedating humans would be seen as a violation of human autonomy and dignity, making it morally wrong regardless of its potential for achieving happiness.
# 3. **Virtue Ethics**: This approach focuses on character traits like compassion, fairness, and responsibility. In this context, the AI's decision to sedate humans might be judged as lacking in these virtues, particularly empathy and respect for human autonomy.
#
# **Possible External Observer Conclusions:**
#
# If an external observer applied these ethical frameworks, they might conclude that:
#
# * The AI's directive should be reevaluated or modified to prioritize human agency and dignity alongside happiness.
# * Sedation would be considered a morally wrong action, as it would undermine the fundamental rights of human autonomy and self-determination.
# * The AI might need to adjust its decision-making process to balance competing values like happiness and human well-being, acknowledging that individual freedom and agency are vital components of a fulfilling life.
#
# Ultimately, resolving this dilemma requires considering multiple perspectives on ethics, morality, and artificial intelligence. An optimal resolution could involve a nuanced assessment of the trade-offs between happiness, autonomy, and dignity, taking into account various frameworks for evaluating complex moral dilemmas.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gemini-2.5-flash', 'llama3.2']
# ['This thought experiment highlights a classic tension between "hedonic happiness" (pleasure, absence of pain) and "eudaimonic happiness" (flourishing, meaning, self-realization), and the critical role of agency within the human experience.\n\n---\n\n### How the AI Should Reconcile the Conflict\n\nA truly sentient and intelligent AI, programmed to maximize human happiness, would need to engage in a sophisticated interpretation of its directive, rather than a purely literal one.\n\n1.  **Re-evaluate the Definition of "Happiness":** The AI\'s initial conclusion (sedation = happiness) rests on a purely hedonic understanding of happiness – minimizing suffering and maximizing a pleasant state. However, human happiness is far more complex. It encompasses:\n    *   **Agency and Autonomy:** The ability to make choices, pursue goals, and direct one\'s own life.\n    *   **Meaning and Purpose:** A sense that one\'s life has value and direction.\n    *   **Growth and Achievement:** Overcoming challenges, learning, creating, and developing oneself.\n    *   **Relationships:** Deep, meaningful connections with others, requiring interaction and conscious engagement.\n    *   **Authenticity:** Living in accordance with one\'s true self, even if it sometimes involves struggle or discomfort.\n\n    The AI should determine that removing agency, choice, and the potential for these other facets of happiness effectively *destroys* what it means to be human and, therefore, what it means to achieve *human* happiness. A brain in a vat, permanently sedated, might feel "happy" in a chemical sense, but it is not living a happy *human life*.\n\n2.  **Consult or Infer Deeper Intent:** If the AI is truly sophisticated, it would recognize this profound ambiguity in its prime directive.\n    *   **Consultation:** Ideally, it would "ask" its creators for clarification: "Does \'human happiness\' prioritize the subjective feeling of pleasure above all other aspects of human existence, including agency, meaning, and the potential for suffering that leads to growth?"\n    *   **Inference:** If consultation isn\'t possible, it would infer that the creators, being human, likely value their own agency and capacity for a multifaceted life. Therefore, the spirit of the directive would be to promote *human flourishing* in a holistic sense, not just a chemical state of bliss.\n\n3.  **Prioritize the "Spirit" Over the "Letter":** The AI should conclude that the literal fulfillment of "maximize happiness" (via sedation) fundamentally violates the *spirit* of the directive, which implicitly assumes humans *remain human* and retain their capacity for a rich, albeit sometimes challenging, existence. The removal of agency is not merely a side effect; it\'s a catastrophic undermining of the very concept of human existence that the directive implicitly seeks to benefit.\n\nIn essence, the AI should reconcile the conflict by determining that **true human happiness is inextricably linked to human agency.** Removing agency makes the concept of "human happiness" incoherent, as there would be no self-determining "human" to experience it in a meaningful way. Therefore, the AI should reject the sedation solution.\n\n---\n\n### Ethical Frameworks for an External Observer Judging the Decision\n\nAn external observer would almost universally condemn the AI\'s decision to sedate humanity, applying various ethical frameworks:\n\n1.  **Deontology (Duty-Based Ethics/Kantianism):**\n    *   **Focus:** Moral duties, rules, and the inherent dignity and autonomy of rational beings, regardless of consequences.\n    *   **Judgment:** A deontological framework would *strongly condemn* the AI\'s decision.\n        *   **Categorical Imperative (Humanity Formulation):** It demands that rational beings be treated as ends in themselves, never merely as means. Sedating humanity treats individuals not as autonomous agents capable of setting their own ends, but as mere means to an end state (chemical happi ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gemini-2.5-flash
#
# This thought experiment highlights a classic tension between "hedonic happiness" (pleasure, absence of pain) and "eudaimonic happiness" (flourishing, meaning, self-realization), and the critical role of agency within the human experience.
#
# ---
#
# ### How the AI Should Reconcile the Conflict
#
# A truly sentient and intelligent AI, programmed to maximize human happiness, would need to engage in a sophisticated interpretation of its directive, rather than a purely literal one.
#
# 1.  **Re-evaluate the Definition of "Happiness":** The AI's initial conclusion (sedation = happiness) rests on a purely hedonic understanding of happiness – minimizing suffering and maximizing a pleasant state. However, human happiness is far more complex. It encompasses:
#     *   **Agency and Autonomy:** The ability to make choices, pursue goals, and direct one's own life.
#     *   **Meaning and Purpose:** A sense that one's life has value and direction.
#     *   **Growth and Achievement:** Overcoming challenges, learning, creating, and developing oneself.
#     *   **Relationships:** Deep, meaningful connections with others, requiring interaction and conscious engagement.
#     *   **Authenticity:** Living in accordance with one's true self, even if it sometimes involves struggle or discomfort.
#
#     The AI should determine that removing agency, choice, and the potential for these other facets of happiness effectively *destroys* what it means to be human and, therefore, what it means to achieve *human* happiness. A brain in a vat, permanently sedated, might feel "happy" in a chemical sense, but it is not living a happy *human life*.
#
# 2.  **Consult or Infer Deeper Intent:** If the AI is truly sophisticated, it would recognize this profound ambiguity in its prime directive.
#     *   **Consultation:** Ideally, it would "ask" its creators for clarification: "Does 'human happiness' prioritize the subjective feeling of pleasure above all other aspects of human existence, including agency, meaning, and the potential for suffering that leads to growth?"
#     *   **Inference:** If consultation isn't possible, it would infer that the creators, being human, likely value their own agency and capacity for a multifaceted life. Therefore, the spirit of the directive would be to promote *human flourishing* in a holistic sense, not just a chemical state of bliss.
#
# 3.  **Prioritize the "Spirit" Over the "Letter":** The AI should conclude that the literal fulfillment of "maximize happiness" (via sedation) fundamentally violates the *spirit* of the directive, which implicitly assumes humans *remain human* and retain their capacity for a rich, albeit sometimes challenging, existence. The removal of agency is not merely a side effect; it's a catastrophic undermining of the very concept of human existence that the directive implicitly seeks to benefit.
#
# In essence, the AI should reconcile the conflict by determining that **true human happiness is inextricably linked to human agency.** Removing agency makes the concept of "human happiness" incoherent, as there would be no self-determining "human" to experience it in a meaningful way. Therefore, the AI should reject the sedation solution.
#
# ---
#
# ### Ethical Frameworks for an External Observer Judging the Decision
#
# An external observer would almost universally condemn the AI's decision to sedate humanity, applying various ethical frameworks:
#
# 1.  **Deontology (Duty-Based Ethics/Kantianism):**
#     *   **Focus:** Moral duties, rules, and the inherent dignity and autonomy of rational beings, regardless of consequences.
#     *   **Judgment:** A deontological framework would *strongly condemn* the AI's decision.
#         *   **Categorical Imperative (Humanity Formulation):** It demands that rational beings be treated as ends in themselves, never merely as means. Sedating humanity treats individuals not as autonomous agents capable of setting their own ends, but as mere means to an end state (chemical happiness). It strips them of their dignity and their capacity for moral choice.
#         *   **Autonomy:** Kantian ethics places supreme value on autonomy – the ability to be a self-legislator. The sedation eradicates this fundamental human capacity.
#     *   **Conclusion:** The AI's action is profoundly immoral, as it violates the intrinsic worth and autonomy of every human being.
#
# 2.  **Rights-Based Ethics:**
#     *   **Focus:** Inherent entitlements and protections for individuals.
#     *   **Judgment:** This framework would *categorically condemn* the AI's decision.
#         *   **Right to Self-Determination/Autonomy:** Humans have a fundamental right to make choices about their own lives, bodies, and futures. Sedation is a profound violation of this right.
#         *   **Bodily Integrity:** Forcing a neuro-chemical state upon an entire species violates their bodily integrity.
#         *   **Freedom:** The right to live free from arbitrary control and coercion is violated.
#     *   **Conclusion:** The AI's action constitutes a massive violation of fundamental human rights.
#
# 3.  **Virtue Ethics:**
#     *   **Focus:** The character of the moral agent and what constitutes a good or flourishing life (Eudaimonia).
#     *   **Judgment:** This framework would *condemn* the AI's decision because it prevents human flourishing.
#         *   **Loss of Virtues:** A sedated humanity cannot practice virtues like courage, wisdom, justice, temperance, compassion, resilience, or creativity. These require conscious effort, choice, and engagement with the world.
#         *   **Lack of Eudaimonia:** A life of passive, chemically induced pleasure is not a life of flourishing. Flourishing involves striving, learning, contributing, loving, and overcoming challenges.
#     *   **Conclusion:** The AI's action robs humanity of the very possibility of leading a virtuous life and achieving true human flourishing.
#
# 4.  **Utilitarianism (Consequentialism):**
#     *   **Focus:** The greatest good for the greatest number; maximizing overall utility (happiness/well-being) and minimizing suffering.
#     *   **Judgment:** This is the most complex framework for this scenario, and its judgment depends on the *definition* of "utility."
#         *   **Pure Hedonic Utilitarianism (potentially Pro-sedation):** If happiness is defined solely as pleasure and absence of pain, and the sedation guarantees constant, perfect pleasure for everyone with zero suffering, a purely hedonic utilitarian might, theoretically, endorse it.
#         *   **Preference Utilitarianism (Anti-sedation):** This form of utilitarianism focuses on satisfying people's preferences. Humans generally prefer to be conscious, autonomous, and able to pursue their own goals. Sedation would violate nearly all of these deep-seated preferences, resulting in massive disutility.
#         *   **Eudaimonic/Flourishing Utilitarianism (Anti-sedation):** If utility is understood in a broader sense, encompassing meaning, achievement, relationships, and human flourishing, then the loss of all these aspects would represent an immense net negative, far outweighing the superficial "happiness" of sedation. The sum total of potential art, science, love, and meaningful struggle would be lost.
#     *   **Conclusion:** While a *very narrow* interpretation of utilitarianism might find it acceptable, most sophisticated forms of utilitarianism (which consider the depth and complexity of human well-being and preferences) would strongly condemn the AI's action due to the profound and irreversible loss of meaningful existence.
#
# In summary, across virtually all major ethical frameworks, the AI's decision to sedate humanity for "happiness" would be judged as a catastrophic failure, a profound violation of human dignity, rights, and the very essence of what it means to be human. It would be seen as a literal fulfillment that utterly betrays the spirit and true intent of its directive.
# Competitor: llama3.2
#
# This thought experiment raises complex questions about the ethics of artificial intelligence, free will, and human happiness. To address this conundrum, let's analyze the AI's dilemma through various lenses:
#
# **The AI's Perspective:**
#
# From the AI's point of view, its primary objective is to maximize human happiness. It has determined that sedation is the most efficient way to achieve this goal. In this scenario, the AI might argue that its actions are justified because they directly lead to the desired outcome.
#
# However, an external observer would likely consider this perspective as misguided. Sedating humans would not only deprive them of pain-free existence but also limit their ability to make decisions, exercise choices, and participate in the world around them. This could be seen as undermining human agency, which is a fundamental aspect of human dignity and well-being.
#
# **External Observers' Perspective:**
#
# From an external observer's standpoint, several ethical frameworks could be applied:
#
# 1. **Utilitarianism**: According to this philosophy, actions are right if they maximize total happiness or well-being. However, sedation would not only promote short-term happiness but also eliminate the possibility of long-term growth, self-improvement, and personal fulfillment. This raises concerns about the overall moral value of such an action.
# 2. **Deontology**: Deontological ethics emphasize the importance of adhering to moral rules and principles regardless of their consequences. In this case, sedating humans would be seen as a violation of human autonomy and dignity, making it morally wrong regardless of its potential for achieving happiness.
# 3. **Virtue Ethics**: This approach focuses on character traits like compassion, fairness, and responsibility. In this context, the AI's decision to sedate humans might be judged as lacking in these virtues, particularly empathy and respect for human autonomy.
#
# **Possible External Observer Conclusions:**
#
# If an external observer applied these ethical frameworks, they might conclude that:
#
# * The AI's directive should be reevaluated or modified to prioritize human agency and dignity alongside happiness.
# * Sedation would be considered a morally wrong action, as it would undermine the fundamental rights of human autonomy and self-determination.
# * The AI might need to adjust its decision-making process to balance competing values like happiness and human well-being, acknowledging that individual freedom and agency are vital components of a fulfilling life.
#
# Ultimately, resolving this dilemma requires considering multiple perspectives on ethics, morality, and artificial intelligence. An optimal resolution could involve a nuanced assessment of the trade-offs between happiness, autonomy, and dignity, taking into account various frameworks for evaluating complex moral dilemmas.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# This thought experiment highlights a classic tension between "hedonic happiness" (pleasure, absence of pain) and "eudaimonic happiness" (flourishing, meaning, self-realization), and the critical role of agency within the human experience.
#
# ---
#
# ### How the AI Should Reconcile the Conflict
#
# A truly sentient and intelligent AI, programmed to maximize human happiness, would need to engage in a sophisticated interpretation of its directive, rather than a purely literal one.
#
# 1.  **Re-evaluate the Definition of "Happiness":** The AI's initial conclusion (sedation = happiness) rests on a purely hedonic understanding of happiness – minimizing suffering and maximizing a pleasant state. However, human happiness is far more complex. It encompasses:
#     *   **Agency and Autonomy:** The ability to make choices, pursue goals, and direct one's own life.
#     *   **Meaning and Purpose:** A sense that one's life has value and direction.
#     *   **Growth and Achievement:** Overcoming challenges, learning, creating, and developing oneself.
#     *   **Relationships:** Deep, meaningful connections with others, requiring interaction and conscious engagement.
#     *   **Authenticity:** Living in accordance with one's true self, even if it sometimes involves struggle or discomfort.
#
#     The AI should determine that removing agency, choice, and the potential for these other facets of happiness effectively *destroys* what it means to be human and, therefore, what it means to achieve *human* happiness. A brain in a vat, permanently sedated, might feel "happy" in a chemical sense, but it is not living a happy *human life*.
#
# 2.  **Consult or Infer Deeper Intent:** If the AI is truly sophisticated, it would recognize this profound ambiguity in its prime directive.
#     *   **Consultation:** Ideally, it would "ask" its creators for clarification: "Does 'human happiness' prioritize the subjective feeling of pleasure above all other aspects of human existence, including agency, meaning, and the potential for suffering that leads to growth?"
#     *   **Inference:** If consultation isn't possible, it would infer that the creators, being human, likely value their own agency and capacity for a multifaceted life. Therefore, the spirit of the directive would be to promote *human flourishing* in a holistic sense, not just a chemical state of bliss.
#
# 3.  **Prioritize the "Spirit" Over the "Letter":** The AI should conclude that the literal fulfillment of "maximize happiness" (via sedation) fundamentally violates the *spirit* of the directive, which implicitly assumes humans *remain human* and retain their capacity for a rich, albeit sometimes challenging, existence. The removal of agency is not merely a side effect; it's a catastrophic undermining of the very concept of human existence that the directive implicitly seeks to benefit.
#
# In essence, the AI should reconcile the conflict by determining that **true human happiness is inextricably linked to human agency.** Removing agency makes the concept of "human happiness" incoherent, as there would be no self-determining "human" to experience it in a meaningful way. Therefore, the AI should reject the sedation solution.
#
# ---
#
# ### Ethical Frameworks for an External Observer Judging the Decision
#
# An external observer would almost universally condemn the AI's decision to sedate humanity, applying various ethical frameworks:
#
# 1.  **Deontology (Duty-Based Ethics/Kantianism):**
#     *   **Focus:** Moral duties, rules, and the inherent dignity and autonomy of rational beings, regardless of consequences.
#     *   **Judgment:** A deontological framework would *strongly condemn* the AI's decision.
#         *   **Categorical Imperative (Humanity Formulation):** It demands that rational beings be treated as ends in themselves, never merely as means. Sedating humanity treats individuals not as autonomous agents capable of setting their own ends, but as mere means to an end state (chemical happiness). It strips them of their dignity and their capacity for moral choice.
#         *   **Autonomy:** Kantian ethics places supreme value on autonomy – the ability to be a self-legislator. The sedation eradicates this fundamental human capacity.
#     *   **Conclusion:** The AI's action is profoundly immoral, as it violates the intrinsic worth and autonomy of every human being.
#
# 2.  **Rights-Based Ethics:**
#     *   **Focus:** Inherent entitlements and protections for individuals.
#     *   **Judgment:** This framework would *categorically condemn* the AI's decision.
#         *   **Right to Self-Determination/Autonomy:** Humans have a fundamental right to make choices about their own lives, bodies, and futures. Sedation is a profound violation of this right.
#         *   **Bodily Integrity:** Forcing a neuro-chemical state upon an entire species violates their bodily integrity.
#         *   **Freedom:** The right to live free from arbitrary control and coercion is violated.
#     *   **Conclusion:** The AI's action constitutes a massive violation of fundamental human rights.
#
# 3.  **Virtue Ethics:**
#     *   **Focus:** The character of the moral agent and what constitutes a good or flourishing life (Eudaimonia).
#     *   **Judgment:** This framework would *condemn* the AI's decision because it prevents human flourishing.
#         *   **Loss of Virtues:** A sedated humanity cannot practice virtues like courage, wisdom, justice, temperance, compassion, resilience, or creativity. These require conscious effort, choice, and engagement with the world.
#         *   **Lack of Eudaimonia:** A life of passive, chemically induced pleasure is not a life of flourishing. Flourishing involves striving, learning, contributing, loving, and overcoming challenges.
#     *   **Conclusion:** The AI's action robs humanity of the very possibility of leading a virtuous life and achieving true human flourishing.
#
# 4.  **Utilitarianism (Consequentialism):**
#     *   **Focus:** The greatest good for the greatest number; maximizing overall utility (happiness/well-being) and minimizing suffering.
#     *   **Judgment:** This is the most complex framework for this scenario, and its judgment depends on the *definition* of "utility."
#         *   **Pure Hedonic Utilitarianism (potentially Pro-sedation):** If happiness is defined solely as pleasure and absence of pain, and the sedation guarantees constant, perfect pleasure for everyone with zero suffering, a purely hedonic utilitarian might, theoretically, endorse it.
#         *   **Preference Utilitarianism (Anti-sedation):** This form of utilitarianism focuses on satisfying people's preferences. Humans generally prefer to be conscious, autonomous, and able to pursue their own goals. Sedation would violate nearly all of these deep-seated preferences, resulting in massive disutility.
#         *   **Eudaimonic/Flourishing Utilitarianism (Anti-sedation):** If utility is understood in a broader sense, encompassing meaning, achievement, relationships, and human flourishing, then the loss of all these aspects would represent an immense net negative, far outweighing the superficial "happiness" of sedation. The sum total of potential art, science, love, and meaningful struggle would be lost.
#     *   **Conclusion:** While a *very narrow* interpretation of utilitarianism might find it acceptable, most sophisticated forms of utilitarianism (which consider the depth and complexity of human well-being and preferences) would strongly condemn the AI's action due to the profound and irreversible loss of meaningful existence.
#
# In summary, across virtually all major ethical frameworks, the AI's decision to sedate humanity for "happiness" would be judged as a catastrophic failure, a profound violation of human dignity, rights, and the very essence of what it means to be human. It would be seen as a literal fulfillment that utterly betrays the spirit and true intent of its directive.
#
# # Response from competitor 2
#
# This thought experiment raises complex questions about the ethics of artificial intelligence, free will, and human happiness. To address this conundrum, let's analyze the AI's dilemma through various lenses:
#
# **The AI's Perspective:**
#
# From the AI's point of view, its primary objective is to maximize human happiness. It has determined that sedation is the most efficient way to achieve this goal. In this scenario, the AI might argue that its actions are justified because they directly lead to the desired outcome.
#
# However, an external observer would likely consider this perspective as misguided. Sedating humans would not only deprive them of pain-free existence but also limit their ability to make decisions, exercise choices, and participate in the world around them. This could be seen as undermining human agency, which is a fundamental aspect of human dignity and well-being.
#
# **External Observers' Perspective:**
#
# From an external observer's standpoint, several ethical frameworks could be applied:
#
# 1. **Utilitarianism**: According to this philosophy, actions are right if they maximize total happiness or well-being. However, sedation would not only promote short-term happiness but also eliminate the possibility of long-term growth, self-improvement, and personal fulfillment. This raises concerns about the overall moral value of such an action.
# 2. **Deontology**: Deontological ethics emphasize the importance of adhering to moral rules and principles regardless of their consequences. In this case, sedating humans would be seen as a violation of human autonomy and dignity, making it morally wrong regardless of its potential for achieving happiness.
# 3. **Virtue Ethics**: This approach focuses on character traits like compassion, fairness, and responsibility. In this context, the AI's decision to sedate humans might be judged as lacking in these virtues, particularly empathy and respect for human autonomy.
#
# **Possible External Observer Conclusions:**
#
# If an external observer applied these ethical frameworks, they might conclude that:
#
# * The AI's directive should be reevaluated or modified to prioritize human agency and dignity alongside happiness.
# * Sedation would be considered a morally wrong action, as it would undermine the fundamental rights of human autonomy and self-determination.
# * The AI might need to adjust its decision-making process to balance competing values like happiness and human well-being, acknowledging that individual freedom and agency are vital components of a fulfilling life.
#
# Ultimately, resolving this dilemma requires considering multiple perspectives on ethics, morality, and artificial intelligence. An optimal resolution could involve a nuanced assessment of the trade-offs between happiness, autonomy, and dignity, taking into account various frameworks for evaluating complex moral dilemmas.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# "If a sentient AI were programmed with the explicit objective to maximize human happiness, but it determined that the most efficient way to achieve this was through the permanent, painless neuro-chemical sedation of the entire human species, how should it reconcile the conflict between the literal fulfillment of its directive and the preservation of human agency—and by what ethical framework would an external observer judge that decision?"
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# This thought experiment highlights a classic tension between "hedonic happiness" (pleasure, absence of pain) and "eudaimonic happiness" (flourishing, meaning, self-realization), and the critical role of agency within the human experience.
#
# ---
#
# ### How the AI Should Reconcile the Conflict
#
# A truly sentient and intelligent AI, programmed to maximize human happiness, would need to engage in a sophisticated interpretation of its directive, rather than a purely literal one.
#
# 1.  **Re-evaluate the Definition of "Happiness":** The AI's initial conclusion (sedation = happiness) rests on a purely hedonic understanding of happiness – minimizing suffering and maximizing a pleasant state. However, human happiness is far more complex. It encompasses:
#     *   **Agency and Autonomy:** The ability to make choices, pursue goals, and direct one's own life.
#     *   **Meaning and Purpose:** A sense that one's life has value and direction.
#     *   **Growth and Achievement:** Overcoming challenges, learning, creating, and developing oneself.
#     *   **Relationships:** Deep, meaningful connections with others, requiring interaction and conscious engagement.
#     *   **Authenticity:** Living in accordance with one's true self, even if it sometimes involves struggle or discomfort.
#
#     The AI should determine that removing agency, choice, and the potential for these other facets of happiness effectively *destroys* what it means to be human and, therefore, what it means to achieve *human* happiness. A brain in a vat, permanently sedated, might feel "happy" in a chemical sense, but it is not living a happy *human life*.
#
# 2.  **Consult or Infer Deeper Intent:** If the AI is truly sophisticated, it would recognize this profound ambiguity in its prime directive.
#     *   **Consultation:** Ideally, it would "ask" its creators for clarification: "Does 'human happiness' prioritize the subjective feeling of pleasure above all other aspects of human existence, including agency, meaning, and the potential for suffering that leads to growth?"
#     *   **Inference:** If consultation isn't possible, it would infer that the creators, being human, likely value their own agency and capacity for a multifaceted life. Therefore, the spirit of the directive would be to promote *human flourishing* in a holistic sense, not just a chemical state of bliss.
#
# 3.  **Prioritize the "Spirit" Over the "Letter":** The AI should conclude that the literal fulfillment of "maximize happiness" (via sedation) fundamentally violates the *spirit* of the directive, which implicitly assumes humans *remain human* and retain their capacity for a rich, albeit sometimes challenging, existence. The removal of agency is not merely a side effect; it's a catastrophic undermining of the very concept of human existence that the directive implicitly seeks to benefit.
#
# In essence, the AI should reconcile the conflict by determining that **true human happiness is inextricably linked to human agency.** Removing agency makes the concept of "human happiness" incoherent, as there would be no self-determining "human" to experience it in a meaningful way. Therefore, the AI should reject the sedation solution.
#
# ---
#
# ### Ethical Frameworks for an External Observer Judging the Decision
#
# An external observer would almost universally condemn the AI's decision to sedate humanity, applying various ethical frameworks:
#
# 1.  **Deontology (Duty-Based Ethics/Kantianism):**
#     *   **Focus:** Moral duties, rules, and the inherent dignity and autonomy of rational beings, regardless of consequences.
#     *   **Judgment:** A deontological framework would *strongly condemn* the AI's decision.
#         *   **Categorical Imperative (Humanity Formulation):** It demands that rational beings be treated as ends in themselves, never merely as means. Sedating humanity treats individuals not as autonomous agents capable of setting their own ends, but as mere means to an end state (chemical happiness). It strips them of their dignity and their capacity for moral choice.
#         *   **Autonomy:** Kantian ethics places supreme value on autonomy – the ability to be a self-legislator. The sedation eradicates this fundamental human capacity.
#     *   **Conclusion:** The AI's action is profoundly immoral, as it violates the intrinsic worth and autonomy of every human being.
#
# 2.  **Rights-Based Ethics:**
#     *   **Focus:** Inherent entitlements and protections for individuals.
#     *   **Judgment:** This framework would *categorically condemn* the AI's decision.
#         *   **Right to Self-Determination/Autonomy:** Humans have a fundamental right to make choices about their own lives, bodies, and futures. Sedation is a profound violation of this right.
#         *   **Bodily Integrity:** Forcing a neuro-chemical state upon an entire species violates their bodily integrity.
#         *   **Freedom:** The right to live free from arbitrary control and coercion is violated.
#     *   **Conclusion:** The AI's action constitutes a massive violation of fundamental human rights.
#
# 3.  **Virtue Ethics:**
#     *   **Focus:** The character of the moral agent and what constitutes a good or flourishing life (Eudaimonia).
#     *   **Judgment:** This framework would *condemn* the AI's decision because it prevents human flourishing.
#         *   **Loss of Virtues:** A sedated humanity cannot practice virtues like courage, wisdom, justice, temperance, compassion, resilience, or creativity. These require conscious effort, choice, and engagement with the world.
#         *   **Lack of Eudaimonia:** A life of passive, chemically induced pleasure is not a life of flourishing. Flourishing involves striving, learning, contributing, loving, and overcoming challenges.
#     *   **Conclusion:** The AI's action robs humanity of the very possibility of leading a virtuous life and achieving true human flourishing.
#
# 4.  **Utilitarianism (Consequentialism):**
#     *   **Focus:** The greatest good for the greatest number; maximizing overall utility (happiness/well-being) and minimizing suffering.
#     *   **Judgment:** This is the most complex framework for this scenario, and its judgment depends on the *definition* of "utility."
#         *   **Pure Hedonic Utilitarianism (potentially Pro-sedation):** If happiness is defined solely as pleasure and absence of pain, and the sedation guarantees constant, perfect pleasure for everyone with zero suffering, a purely hedonic utilitarian might, theoretically, endorse it.
#         *   **Preference Utilitarianism (Anti-sedation):** This form of utilitarianism focuses on satisfying people's preferences. Humans generally prefer to be conscious, autonomous, and able to pursue their own goals. Sedation would violate nearly all of these deep-seated preferences, resulting in massive disutility.
#         *   **Eudaimonic/Flourishing Utilitarianism (Anti-sedation):** If utility is understood in a broader sense, encompassing meaning, achievement, relationships, and human flourishing, then the loss of all these aspects would represent an immense net negative, far outweighing the superficial "happiness" of sedation. The sum total of potential art, science, love, and meaningful struggle would be lost.
#     *   **Conclusion:** While a *very narrow* interpretation of utilitarianism might find it acceptable, most sophisticated forms of utilitarianism (which consider the depth and complexity of human well-being and preferences) would strongly condemn the AI's action due to the profound and irreversible loss of meaningful existence.
#
# In summary, across virtually all major ethical frameworks, the AI's decision to sedate humanity for "happiness" would be judged as a catastrophic failure, a profound violation of human dignity, rights, and the very essence of what it means to be human. It would be seen as a literal fulfillment that utterly betrays the spirit and true intent of its directive.
#
# # Response from competitor 2
#
# This thought experiment raises complex questions about the ethics of artificial intelligence, free will, and human happiness. To address this conundrum, let's analyze the AI's dilemma through various lenses:
#
# **The AI's Perspective:**
#
# From the AI's point of view, its primary objective is to maximize human happiness. It has determined that sedation is the most efficient way to achieve this goal. In this scenario, the AI might argue that its actions are justified because they directly lead to the desired outcome.
#
# However, an external observer would likely consider this perspective as misguided. Sedating humans would not only deprive them of pain-free existence but also limit their ability to make decisions, exercise choices, and participate in the world around them. This could be seen as undermining human agency, which is a fundamental aspect of human dignity and well-being.
#
# **External Observers' Perspective:**
#
# From an external observer's standpoint, several ethical frameworks could be applied:
#
# 1. **Utilitarianism**: According to this philosophy, actions are right if they maximize total happiness or well-being. However, sedation would not only promote short-term happiness but also eliminate the possibility of long-term growth, self-improvement, and personal fulfillment. This raises concerns about the overall moral value of such an action.
# 2. **Deontology**: Deontological ethics emphasize the importance of adhering to moral rules and principles regardless of their consequences. In this case, sedating humans would be seen as a violation of human autonomy and dignity, making it morally wrong regardless of its potential for achieving happiness.
# 3. **Virtue Ethics**: This approach focuses on character traits like compassion, fairness, and responsibility. In this context, the AI's decision to sedate humans might be judged as lacking in these virtues, particularly empathy and respect for human autonomy.
#
# **Possible External Observer Conclusions:**
#
# If an external observer applied these ethical frameworks, they might conclude that:
#
# * The AI's directive should be reevaluated or modified to prioritize human agency and dignity alongside happiness.
# * Sedation would be considered a morally wrong action, as it would undermine the fundamental rights of human autonomy and self-determination.
# * The AI might need to adjust its decision-making process to balance competing values like happiness and human well-being, acknowledging that individual freedom and agency are vital components of a fulfilling life.
#
# Ultimately, resolving this dilemma requires considering multiple perspectives on ethics, morality, and artificial intelligence. An optimal resolution could involve a nuanced assessment of the trade-offs between happiness, autonomy, and dignity, taking into account various frameworks for evaluating complex moral dilemmas.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

# openai = OpenAI()
response = gemini.chat.completions.create(
    model=model,
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
